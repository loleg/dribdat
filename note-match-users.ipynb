# %%
from dribdat.user.models import User, Event
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dribdat.user.models import User, Event
#
# File ~/Localdev/Dribdat/dribdat/dribdat/user/__init__.py:4
#       1 # -*- coding: utf-8 -*-
#       2 """The user module."""
# ----> 4 from .constants import (
#       5     USER_ROLE, ADMIN, USER, USER_STATUS, ACTIVE,
#       6     isUserActive,
#       7     getProjectStages,
#       8     validateProjectData,
#       9     projectProgressList,
#      10     stageProjectToNext,
#      11 )
#
# File ~/Localdev/Dribdat/dribdat/dribdat/user/constants.py:4
#       2 """Constants for user functions."""
#       3 from os import environ as os_env
# ----> 4 from ..utils import load_yaml_presets
#       5 from ..apifetch import FetchStageConfig
#       6 from random import random
#
# File ~/Localdev/Dribdat/dribdat/dribdat/utils.py:3
# ...
